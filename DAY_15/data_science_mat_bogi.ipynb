# %%
import requests
import json


for i in range(1):
    start_room_id = 100000 + (i * 100) + 1
    end_room_id = 100000 + ((i + 1) * 100)
    # print((start_room_id, end_room_id))
    
    BASE_URL = "https://api.zigbang.com/v1/items?detail=true"
    result_url = BASE_URL + "&item_ids=" + "&item_ids=".join([
        str(room_id)
        for room_id
        in range(start_room_id, end_room_id + 1)
    ])
    
    print(result_url)
# Out:
# https://api.zigbang.com/v1/items?detail=true&item_ids=100001&item_ids=100002&item_ids=100003&item_ids=100004&item_ids=100005&item_ids=100006&item_ids=100007&item_ids=100008&item_ids=100009&item_ids=100010&item_ids=100011&item_ids=100012&item_ids=100013&item_ids=100014&item_ids=100015&item_ids=100016&item_ids=100017&item_ids=100018&item_ids=100019&item_ids=100020&item_ids=100021&item_ids=100022&item_ids=100023&item_ids=100024&item_ids=100025&item_ids=100026&item_ids=100027&item_ids=100028&item_ids=100029&item_ids=100030&item_ids=100031&item_ids=100032&item_ids=100033&item_ids=100034&item_ids=100035&item_ids=100036&item_ids=100037&item_ids=100038&item_ids=100039&item_ids=100040&item_ids=100041&item_ids=100042&item_ids=100043&item_ids=100044&item_ids=100045&item_ids=100046&item_ids=100047&item_ids=100048&item_ids=100049&item_ids=100050&item_ids=100051&item_ids=100052&item_ids=100053&item_ids=100054&item_ids=100055&item_ids=100056&item_ids=100057&item_ids=100058&item_ids=100059&item_ids=
# ...

# %%
response = requests.get(result_url)
room_elements = json.loads(response.text)
room_elements
# Out:
# {'count_agent': 55,
#  'count_direct': 2,
#  'items': [{'header': False,
#    'header_height': 0,
#    'item': {'address1': '서울시 성북구 석관동',
#     'address2': '129-16',
#     'address3': None,
#     'agent_address1': '서울시 성북구 석관동 131-51',
#     'agent_email': 'homking1@hanmail.net',
#     'agent_local1': '서울시',
#     'agent_local2': '성북구',
#     'agent_mobile': '010-8792-7459',
#     'agent_name': '미래공인중개사(이종란)',
#     'agent_phone': '010-8792-7459',
#     'bjd_code': '1129013900',
#     'bonbun_code': '129',
#     'bubun_code': '16',
#     'building': None,
#     'building_type': '다세대건물',
#     'contract': '서울특별시',
#     'deposit': 500,
#     'description': '1,6호선 환승 석계역  초입원룸,신축3년차   깨끗하고 환해요.<br />큰마트, 도서관도 있고  맛있는 먹거리도 많아요.<br />즉시입주 가능하고,보증금 조정가능 합니다.',
#     'description_og': '1,6호선 환승 석계역  초입원룸,신축3년차   깨끗하고 환해요.\n큰마트, 도서관도 있고  맛있는 먹거리도 많아요.\n즉시입주 가능하고,보증금 조정가능 합니다.',
#     'elevator': '없음',
#     'floor': '2층',
#     'floor_all': '3층',
#     'id': 100001,
# ...

# %%
import pandas as pd
def get_df_from_zigbang(url):
    response = requests.get(url)
    zigbang_dict = json.loads(response.text)
    df = pd.DataFrame(columns=["address", "deposit", "rent", "phonenumber"])
    for item in zigbang_dict.get('items'):
        room_information = item.get('item')
        try:
            address = room_information.get('agent_address1')
            deposit = room_information.get('deposit')
            rent = room_information.get('rent')
            phonenumber = room_information.get('original_user_phone')
            df.loc[len(df)] = [address, deposit, rent, phonenumber]
        except:
            pass
        
    return df


df_sinsa = get_df_from_zigbang("https://api.zigbang.com/v1/items?detail=true&item_ids=3430448&item_ids=3367854&item_ids=3288446&item_ids=3467204&item_ids=3150497&item_ids=3440906&item_ids=3376834&item_ids=3139708&item_ids=3331511&item_ids=3373198&item_ids=3236734&item_ids=3376434&item_ids=3322860&item_ids=3303061&item_ids=3287167&item_ids=3262172&item_ids=3228631&item_ids=3505011&item_ids=3249401&item_ids=3330951&item_ids=3494055&item_ids=3317227&item_ids=3405679&item_ids=3103384&item_ids=3418616&item_ids=3240028&item_ids=3456814&item_ids=3416910&item_ids=3429455&item_ids=3181675&item_ids=3309372&item_ids=3501566&item_ids=3240513&item_ids=3346510&item_ids=3406670&item_ids=3412596&item_ids=3214438&item_ids=3459715&item_ids=3493254&item_ids=3475114&item_ids=3501607&item_ids=3484623&item_ids=3190410&item_ids=3350050&item_ids=3495453&item_ids=3446619&item_ids=3451078&item_ids=3248718&item_ids=3345445&item_ids=3332380&item_ids=3450803&item_ids=3471049&item_ids=3438747&item_ids=3330749&item_ids=3446920&item_ids=3151682&item_ids=3501554&item_ids=3258532&item_ids=3435418&item_ids=3501551")

# %%
df_samsong = get_df_from_zigbang("https://api.zigbang.com/v1/items?detail=true&item_ids=4525281&item_ids=4605855&item_ids=4554156&item_ids=4403153&item_ids=4606039&item_ids=4554172&item_ids=4578902&item_ids=4578838&item_ids=4584109&item_ids=4486266&item_ids=4386045&item_ids=4402886&item_ids=4432462&item_ids=4443632&item_ids=4581614&item_ids=4381702&item_ids=4527092&item_ids=4549285&item_ids=4402506&item_ids=4602636&item_ids=4497565&item_ids=4511171&item_ids=4443709&item_ids=4429622&item_ids=4403416&item_ids=4432289&item_ids=4079130&item_ids=4437399&item_ids=4429721&item_ids=4578890&item_ids=4602810&item_ids=4429760&item_ids=4291409&item_ids=4509682&item_ids=4557265&item_ids=4525329&item_ids=4605632&item_ids=4293732&item_ids=4462878&item_ids=4549228&item_ids=4549475&item_ids=4509794&item_ids=4432375&item_ids=4497413&item_ids=4402540&item_ids=4066531&item_ids=4605858&item_ids=4355202&item_ids=4460341&item_ids=4313925")

# %%
df_suyu = get_df_from_zigbang("https://api.zigbang.com/v1/items?detail=true&item_ids=4574228&item_ids=4605554&item_ids=4620198&item_ids=4601198&item_ids=4620060&item_ids=4520711&item_ids=4548133&item_ids=4506592&item_ids=4589612&item_ids=4505100&item_ids=4516470&item_ids=4587412&item_ids=4571118&item_ids=4384849&item_ids=4608071&item_ids=4552754&item_ids=4571852&item_ids=4531701&item_ids=4603408&item_ids=4489421&item_ids=4606360&item_ids=4241248&item_ids=4542176&item_ids=4312716&item_ids=4559931&item_ids=4611531&item_ids=3959019&item_ids=4415510&item_ids=4582180&item_ids=4599175&item_ids=4613515&item_ids=4607800&item_ids=4505755&item_ids=4556271&item_ids=4416073&item_ids=4355236&item_ids=4587993&item_ids=4497166&item_ids=4525106&item_ids=4574647&item_ids=4529116&item_ids=4537368&item_ids=4345009&item_ids=4561691&item_ids=4195122&item_ids=4596886&item_ids=4440388&item_ids=4606341&item_ids=4511248&item_ids=4314546&item_ids=4564124&item_ids=4378242&item_ids=4578403&item_ids=4366297&item_ids=4525553&item_ids=4577058&item_ids=4467591&item_ids=4420813&item_ids=4497112&item_ids=4206980")

# %%
df_sinsa.head()
# Out:
#                         address  deposit   rent    phonenumber
# 0        서울특별시 강남구 신사동 610-2 1층   5000.0   65.0  010-9134-5291
# 1  서울특별시 강남구 논현동 108 웰스톤상가 B101   3000.0   95.0  010-4166-1970
# 2  서울특별시 강남구 봉은사로25길 13 1층(논현동)     65.0   65.0  010-8886-5877
# 3            서울특별시 강남구 역삼로17길 9   2000.0  150.0  010-2331-8811
# 4  서울특별시 강남구 역삼동 625-10 커피한잔부동산    500.0   67.0  010-3877-0714

# %%
df_samsong.head()
# Out:
#                         address  deposit  rent    phonenumber
# 0      경기도 고양시 덕양구 삼송동 356-6 1층  16000.0   0.0  010-8482-0775
# 1        경기도 고양시 덕양구 원흥동 639-3   16000.0   0.0  010-4640-2446
# 2          경기도 고양시 덕양구 원흥동639-2  38000.0   0.0  010-8212-9612
# 3        경기도 고양시 덕양구 원흥동 639-3   21000.0   0.0  010-4640-2446
# 4  경기도 고양시 덕양구 삼원로22, 102호(삼송동)  10000.0   0.0  010-3209-8100

# %%
df_samsong.mean()
# Out:
# deposit    15440.0
# rent          22.1
# dtype: float64

# %%
df_sinsa.mean()
# Out:
# deposit    2808.842105
# rent         78.421053
# dtype: float64

# %%
# %matplotlib inline

# %%
df_sinsa.hist("deposit")
df_sinsa.hist("rent")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fec05331d68>]], dtype=object)

# %%
df_samsong.hist("deposit", color="Red")
df_samsong.hist("rent", color="Red")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fec050f22e8>]], dtype=object)

# %%
ax = df_sinsa.plot.scatter(x="deposit", y="rent", color="Blue")
df_suyu.plot.scatter(x="deposit", y="rent", color="Red", ax=ax)

# %%
# pandas - pydata
import pandas as pd

# %%
# DataFrame 이라는 자료형 - 생성하는 방법 두가지 ( 쌩으로 or 데이터를 읽어서 )

# %%
pd.read_csv("../../users.csv")
# Out:
#        금정             서울특별시 담훈강군   지홍환동 949 437-675
# 0     현환휘         인천광역시 규준시 솔승엽시 1462 3-1 (449-926)
# 1     묘선아              서울특별시 정미균구 미태선거리 0 (863-003)
# 2     영구정                 강원도 기완군   아림동 946 406-620
# 3      차익                 광주광역시 균웅군   균양동 8 660-377
# 4     궉지강              서울특별시 힘효시 엽은욱동 084 (144-077)
# 5     준솔강        전라남도 건효군 영범종거리 463 669-5 (729-039)
# 6     해후은  서울특별시 준향마을 현영솔거리 493 704동 289호 (480-350)
# 7     권미비          부산광역시 미남구 노수환로 367 4-4 (399-031)
# 8      삼미                 강원도 완람마을   덕명휘동 3 196-942
# 9      송혜           전라남도 욱림마을   수명형거리 4 726 205-520
# 10     부세            충청남도 슬진구 람명완동 8 39-9 (379-447)
# 11    원진온  울산광역시 동방원열시   다강지동 955 907동 999호 494-812
# 12   소봉슬하             제주특별자치도 엽성주구 혜무진로 0 (543-425)
# 13    신찬금                경기도 상람마을   솔세위마을 7 603-801
# 14    주안비           전라남도 명철려시   힘림동 2 128-9 864-213
# 15     하위    부산광역시 장곡성해시   건한주동 9 064동 955호 780-782
# 16    증련협                전라북도 제선주구 구향위동 0 (992-903)
# ...

# %%
df = pd.DataFrame(columns=["address", "deposit", "rent", "phonenumber"])
df
# Out:
# Empty DataFrame
# Columns: [address, deposit, rent, phonenumber]
# Index: []

# %%
df.loc[0] = ["주소", 1000, 100, "01022205736"]

# %%
df.loc[1] = ["주소", 1000, 100, "01022205736"]

# %%
df.loc[2] = ["주소", 1000, 100, "01022205736"]

# %%
df.loc[len(df)] = ["주소", 1000, 100, "01022205736"]

# %%
df
# Out:
#   address  deposit   rent  phonenumber
# 0      주소   1000.0  100.0  01022205736
# 1      주소   1000.0  100.0  01022205736
# 2      주소   1000.0  100.0  01022205736
# 3      주소   1000.0  100.0  01022205736
# 4      주소   1000.0  100.0  01022205736
# 5      주소   1000.0  100.0  01022205736
# 6      주소   1000.0  100.0  01022205736
# 7      주소   1000.0  100.0  01022205736
# 8      주소   1000.0  100.0  01022205736

# %%
df.head()
# Out:
#   address  deposit   rent  phonenumber
# 0      주소   1000.0  100.0  01022205736
# 1      주소   1000.0  100.0  01022205736
# 2      주소   1000.0  100.0  01022205736
# 3      주소   1000.0  100.0  01022205736
# 4      주소   1000.0  100.0  01022205736

# %%
df.tail()
# Out:
#   address  deposit   rent  phonenumber
# 4      주소   1000.0  100.0  01022205736
# 5      주소   1000.0  100.0  01022205736
# 6      주소   1000.0  100.0  01022205736
# 7      주소   1000.0  100.0  01022205736
# 8      주소   1000.0  100.0  01022205736
